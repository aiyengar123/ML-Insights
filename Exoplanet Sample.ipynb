# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# # Loading in Dataset

# %%
df = pd.read_csv("Exoplanet extract new.csv")

# %%
df.head()
# Out:
#    rowid pl_hostname pl_letter     pl_name    pl_discmethod  pl_pnum  \
# 0      1      11 Com         b    11 Com b  Radial Velocity        1
# 1      2      11 UMi         b    11 UMi b  Radial Velocity        1
# 2      3      14 And         b    14 And b  Radial Velocity        1
# 3      4      14 Her         b    14 Her b  Radial Velocity        1
# 4      5    16 Cyg B         b  16 Cyg B b  Radial Velocity        1
#
#     pl_orbper  pl_orbpererr1  pl_orbpererr2  pl_orbperlim  ...  st_bmy  \
# 0   326.03000           0.32          -0.32           0.0  ...     NaN
# 1   516.21997           3.20          -3.20           0.0  ...     NaN
# 2   185.84000           0.23          -0.23           0.0  ...     NaN
# 3  1773.40002           2.50          -2.50           0.0  ...   0.537
# 4   798.50000           1.00          -1.00           0.0  ...   0.418
#
#    st_bmyerr  st_bmylim  st_m1  st_m1err  st_m1lim  st_c1  st_c1err  st_c1lim  \
# ...

# %%
df.shape
# Out:
# (3838, 355)

# %% [markdown]
# # Comments on Habitability

# %%
#K2-18 (b and c) are known habitable 
#spectral type of host star is important - M-type is what K2-18b orbits
#circumsteller habitable zone (because it is hard to measure qualities of exoplanets especially surface temperature)
#K2-18b is 2.3 times wider and 8 times more massive than Earth
#research question #1: what conditions need to exist for liquid water
#Luminosity is useful in determining the CHZ because it affects the temperature of surrounding planets; a star with low luminosity will have a much closer CHZ than a star with high luminosity.

# %% [markdown]
# # What conditions need to exist for liquid water?

# %% [markdown]
# # Calculating Habitability Zones (Morris Method - Apparent Magnitude)

# %% [markdown]
# https://www.planetarybiology.com/calculating_habitable_zone.html

# %%
df=df.sort_values(by=["st_optmag"],ascending=False)

# %%
print(df[["pl_hostname","pl_name","pl_orbsmax","st_dist","st_optmag","st_spstr"]])
# Out:
#                       pl_hostname                        pl_name  pl_orbsmax  \
# 13        2MASS J12073346-3932539      2MASS J12073346-3932539 b    46.00000
# 3610                    SWEEPS-11                    SWEEPS-11 b     0.03000
# 3618                   TRAPPIST-1                   TRAPPIST-1 f     0.03710
# 3614                   TRAPPIST-1                   TRAPPIST-1 b     0.01111
# 3611                     SWEEPS-4                     SWEEPS-4 b     0.05500
# ...                           ...                            ...         ...
# 3782                      WASP-97                      WASP-97 b         NaN
# 3783                      WASP-98                      WASP-98 b     0.03762
# 3784                      WASP-99                      WASP-99 b         NaN
# 3785                  WD 0806-661                  WD 0806-661 b  2500.00000
# 3786  WISEP J121756.91+162640.2 A  WISEP J121756.91+162640.2 A b     8.00000
#
#       st_dist  st_optmag st_spstr
# ...

# %% [markdown]
# # Orbital Period?

# %%
df.sort_values(by=["pl_orbper"])
# Out:
#       rowid                  pl_hostname pl_letter  \
# 3593   3594               PSR J1719-1438         b
# 838     839                       K2-137         b
# 1152   1153                 KIC 10001893         b
# 1180   1181                       KOI-55         b
# 847     848                       K2-141         b
# ...     ...                          ...       ...
# 3632   3633                USco CTIO 108         b
# 3637   3638      VHS J125601.92-125723.9         b
# 3785   3786                  WD 0806-661         b
# 3786   3787  WISEP J121756.91+162640.2 A         b
# 3816   3817                      kap And         b
#
#                             pl_name                  pl_discmethod  pl_pnum  \
# 3593               PSR J1719-1438 b                  Pulsar Timing        1
# 838                        K2-137 b                        Transit        1
# 1152                 KIC 10001893 b  Orbital Brightness Modulation        3
# ...

# %% [markdown]
# # A Habitable Candidate - K2-18

# %%
df.loc[df["pl_hostname"]=="K2-18"]
# Out:
#      rowid pl_hostname pl_letter  pl_name    pl_discmethod  pl_pnum  \
# 897    898       K2-18         b  K2-18 b          Transit        2
# 898    899       K2-18         c  K2-18 c  Radial Velocity        2
#
#      pl_orbper  pl_orbpererr1  pl_orbpererr2  pl_orbperlim  ...  st_jmh2  \
# 897   32.93963         0.0001        -0.0001           0.0  ...    0.628
# 898    8.96200         0.0080        -0.0080           0.0  ...    0.628
#
#      st_jmh2err  st_jmh2lim  st_hmk2  st_hmk2err  st_hmk2lim  st_jmk2  \
# 897       0.038         0.0    0.236       0.032         0.0    0.864
# 898       0.038         0.0    0.236       0.032         0.0    0.864
#
#      st_jmk2err st_jmk2lim  st_colorn
# 897       0.034        0.0          4
# 898       0.034        0.0          4
#
# [2 rows x 147 columns]

# %%
#K2-18 (b and c)
#spectral type of host star is important - M-type is what K2-18b orbits
#circumsteller habitable zone (because it is hard to measure qualities of exoplanets especially surface temperature)
#K2-18b is 2.3 times wider and 8 times more massive than Earth
#research question #1: what conditions need to exist for liquid water
#Luminosity is useful in determining the CHZ because it affects the temperature of surrounding planets; a star with low luminosity will have a much closer CHZ than a star with high luminosity.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-47173b6beb47> in <module>()
# ----> 1 K2-18 (b and c)
#
# NameError: name 'K2' is not defined
